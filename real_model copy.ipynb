# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("thursday_plus_cleaned.csv", skipinitialspace=True, encoding = 'latin-1')
encoder = LabelEncoder()
df['Label'] = encoder.fit_transform(df['Label'])  
y_encoded = encoder.fit_transform(df['Label'])
#X = df[['Flow Duration', 
        #'Fwd Packet Length Mean', 
        #'Bwd Packet Length Std', 
        #'Packet Length Variance', 
        #'Average Packet Size']]
X = df.iloc[:, 0:85]
y = df['Label']
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, random_state=42, stratify=y_encoded, test_size = 0.2)
df.head()
# Out:
#                                    Flow ID  Src Port  Dst Port  Protocol  \
# 0                    8.6.0.1-8.0.6.4-0-0-0         0         0         0
# 1   192.168.10.50-192.168.10.3-33898-389-6     33898       389         6
# 2   192.168.10.50-192.168.10.3-33904-389-6     33904       389         6
# 3   192.168.10.19-192.168.10.3-32794-389-6     32794       389         6
# 4  192.168.10.19-192.168.10.3-44766-3268-6     44766      3268         6
#
#    Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0      119945515               150                  0
# 1      113095465                48                 24
# 2      113473706                68                 40
# 3      118034439               106                 61
# 4      116446503                72                 47
#
#    Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                           0                           0
# 1                        9668                       10012
# 2                       11364                       12718
# 3                       17896                       27110
# 4                       13380                       15294
#
#    Fwd Packet Length Max  ...  Active Max  Active Min    Idle Mean  \
# 0                      0  ...    20364643           6  24368817.25
# 1                    403  ...     1629110         379  13821156.00
# 2                    403  ...     1424245         325  13846819.13
# 3                   1313  ...     3343206      636188  21923231.40
# 4                   1313  ...     3552487         296  28210375.75
#
#        Idle Std  Idle Max  Idle Min  ICMP Code  ICMP Type  \
# 0  2.431326e+07  60127797   5702188         -1         -1
# 1  4.277541e+06  16482821   6737603         -1         -1
# 2  4.229413e+06  16482853   6945512         -1         -1
# 3  1.681534e+07  49024651   6604342         -1         -1
# 4  1.591666e+07  49206703  11080571         -1         -1
#
#    Total TCP Flow Time  Label
# 0                    0      0
# 1            113095465      0
# 2            113473706      0
# 3            118034439      0
# 4            116446503      0
#
# [5 rows x 86 columns]

# %%
X_train = X_train.select_dtypes(include=[np.number])
X_test = X_test.select_dtypes(include=[np.number])
X_train.dtypes
# Out:
# Src Port               int64
# Dst Port               int64
# Protocol               int64
# Flow Duration          int64
# Total Fwd Packet       int64
#                        ...
# Idle Max               int64
# Idle Min               int64
# ICMP Code              int64
# ICMP Type              int64
# Total TCP Flow Time    int64
# Length: 84, dtype: object

# %%
rfc1 = RandomForestClassifier(class_weight='balanced', random_state=42).fit(X_train, y_train)

# %%
rfc1.predict(X_test)
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %%
y_pred = rfc1.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9998876151944257

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
  "n_estimators": [50,100,200,300],
  "max_depth" : [None, 10, 20, 30],
  "min_samples_split" : [2, 5, 10],
  "min_samples_leaf" : [1,2,4],
  "max_features": ["auto","sqrt"]
}

# %%
rfc2 = RandomForestClassifier()

# %%
#grid_search = GridSearchCV(estimator= rfc2, param_grid = param_grid, cv = 5)

# %%
#grid_search.fit(X_train, y_train)

# %%
#grid_search.best_params_

# %%
#best_rfc2 = grid_search.best_estimator_

# %%
#y_pred_tuned = best_rfc2.predict(X_test)

# %%
#accuracy_score(y_test,y_pred_tuned)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
class_names = encoder.classes_
cm1 = confusion_matrix(y_test, y_pred)
#cm2 = confusion_matrix(y_test, y_pred_tuned)
fig, axes = plt.subplots(1, 2, figsize =(12,5))
disp1 = ConfusionMatrixDisplay(confusion_matrix = cm1, display_labels = class_names)
disp1.plot(ax = axes[0], colorbar = False)
axes[0].set_title("Model 1 Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
disp1 = ConfusionMatrixDisplay(confusion_matrix = cm1, display_labels = class_names)
disp1.plot(ax = axes[0], colorbar = False)
axes[0].set_title("Model 1 Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
#disp2 = ConfusionMatrixDisplay(confusion_matrix = cm2, display_labels=class_names)
#disp2.plot(ax = axes[0], colorbar = False)
#axes[0].set_title("Model 2 Confusion Matrix")

# %%
plt.tight_layout()
plt.show()

# %%
importances = rfc1.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(10, 5))
plt.title("Feature Importances - Model 1")
plt.bar(range(5), importances[indices[:5]])
plt.xticks(range(5), X.columns[indices[:5]], rotation=90)
plt.tight_layout()
plt.show()

# %%
'''
importances = rfc2.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(10, 5))
plt.title("Feature Importances - Model 1")
plt.bar(range(10), importances[indices[:10]])
plt.xticks(range(10), X.columns[indices[:10]], rotation=90)
plt.tight_layout()
plt.show()
'''
# Out:
# '\nimportances = rfc2.feature_importances_\nindices = np.argsort(importances)[::-1]\nplt.figure(figsize=(10, 5))\nplt.title("Feature Importances - Model 1")\nplt.bar(range(10), importances[indices[:10]])\nplt.xticks(range(10), X.columns[indices[:10]], rotation=90)\nplt.tight_layout()\nplt.show()\n'

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
#
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     57432
#            1       1.00      0.86      0.92         7
#            2       1.00      1.00      1.00     13724
#            3       1.00      0.93      0.97        15
#            4       1.00      0.50      0.67         2
#            5       1.00      0.75      0.86         4
#
#     accuracy                           1.00     71184
#    macro avg       1.00      0.84      0.90     71184
# weighted avg       1.00      1.00      1.00     71184

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(rfc1, X_train, y_train, cv=5)
print("Cross-validated accuracy:", scores.mean())
# Out:
# Cross-validated accuracy: 0.9998805899846314

# %% [markdown]
# Generates more samples of under represented attacks for trainning

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00     57432\n           1       1.00      0.86      0.92         7\n           2       1.00      1.00      1.00     13724\n           3       1.00      0.93      0.97        15\n           4       1.00      0.50      0.67         2\n           5       1.00      0.75      0.86         4\n\n    accuracy                           1.00     71184\n   macro avg       1.00      0.84      0.90     71184\nweighted avg       1.00      1.00      1.00     71184\n'

# %%
false_negatives = (y_test != y_pred) & (y_test != 0) & (y_pred == 0)

X_fn = X_test[false_negatives]
y_fn_true = y_test[false_negatives]

# Concatenate for review
fn_df = X_fn.copy()
fn_df['True_Label'] = y_fn_true

# Look at them
fn_df.head()
# Out:
#         Src Port  Dst Port  Protocol  Flow Duration  Total Fwd Packet  \
# 169234     53431       137        17            245                 2
# 234030     44634        80         6       20848310                84
# 133400      1260       444         6      104989439                 9
# 218672     36242        80         6        5017466                 6
# 195268     35626        80         6       53205463               158
#
#         Total Bwd packets  Total Length of Fwd Packet  \
# 169234                  2                         100
# 234030                 44                       16995
# 133400                  9                        2015
# 218672                  6                         599
# 195268                 80                       37362
#
#         Total Length of Bwd Packet  Fwd Packet Length Max  \
# 169234                         458                     50
# 234030                       36979                    602
# 133400                           0                    963
# 218672                        4149                    599
# 195268                      140083                    585
#
#         Fwd Packet Length Min  ...  Active Max  Active Min   Idle Mean  \
# 169234                     50  ...           0           0         0.0
# 234030                      0  ...           0           0         0.0
# 133400                      0  ...     1211670           2  51888689.0
# 218672                      0  ...       12710       12710   5004049.0
# 195268                      0  ...           0           0         0.0
#
#            Idle Std  Idle Max  Idle Min  ICMP Code  ICMP Type  \
# 169234        0.000         0         0         -1         -1
# 234030        0.000         0         0         -1         -1
# 133400  6575244.537  56538089  47239289         -1         -1
# 218672        0.000   5004049   5004049         -1         -1
# 195268        0.000         0         0         -1         -1
#
#         Total TCP Flow Time  True_Label
# 169234                    0           2
# 234030             20848310           3
# 133400           2503850007           1
# 218672              5017466           4
# 195268             53205463           5
#
# [5 rows x 85 columns]

# %%
feat_names = X_train.columns

# Top features
indices = np.argsort(importances)[-10:]
plt.barh(range(len(indices)), importances[indices])
plt.yticks(range(len(indices)), [feat_names[i] for i in indices])
plt.xlabel("Feature Importance")
plt.title("Top Important Features in RFC")
plt.show()

# %%
# Get correctly predicted attack samples (true positives)
tp_mask = (y_test != 0) & (y_test == y_pred)
X_tp = X_test[tp_mask]

# Compare mean feature values of FNs vs TPs
compare = pd.DataFrame({
    "FalseNeg_mean": X_fn.mean(),
    "TruePos_mean": X_tp.mean()
})

# Optional: visualize differences
compare.plot(kind='bar', figsize=(12, 5), title="Feature Means: False Negatives vs True Positives")
plt.xticks(rotation=90)
plt.show()
